# %%
from glob import glob
import subprocess

import numpy as np
import os
from glob import glob
import matplotlib.pyplot as plt
import imageio.v3 as imageio
import json
import cv2
from tqdm import tqdm
import open3d as o3d
import shutil
import mrob
import subprocess
from joblib import Parallel, delayed

from pytorch3d import io
import torch
from pytorch3d.renderer.cameras import FoVPerspectiveCameras, PerspectiveCameras
from pytorch3d.renderer.points.rasterizer import PointsRasterizer, PointsRasterizationSettings
from pytorch3d.structures import Pointclouds
from pytorch3d.utils import cameras_from_opencv_projection 
from pytorch3d.renderer import (
    PointsRenderer,
    NormWeightedCompositor
)

from scene.dataset_readers import readColmapSceneInfo
from utils.camera_utils import loadCam
from collections import namedtuple
import open3d as o3d
import matplotlib.pyplot as plt
import numpy as np
import mrob
from tqdm import tqdm
from joblib import Parallel, delayed
import os
import pickle
import cv2
import fire

from gaussian_renderer import GaussianModel

# %%
def compute_point_cloud_camera_fraction(R, tvec, fx, fy, cx, cy, height, width, points, build_image=False):
    camera_matrix = torch.tensor([[fx, 0, cx],
                               [0, fy, cy],
                               [0,0,1]])
    # R = [camera.R for camera in cameras]
    # tvec = [camera.T for camera in cameras]

    camera_p3d = cameras_from_opencv_projection(R = torch.tensor(np.array(R)).unsqueeze(0).float(), 
                                                tvec = torch.tensor(np.array(tvec)).unsqueeze(0).float(), 
                                                camera_matrix = camera_matrix.unsqueeze(0).float(),
                                                image_size = torch.tensor([height, 
                                                                          width]).unsqueeze(0).float())
    
    raster_settings = PointsRasterizationSettings(
                    image_size=(height, 
                                width), 
                    radius = 0.025,
                    points_per_pixel = 1 
                    )

    # Create a points rasterizer
    

    rasterizer = PointsRasterizer(cameras=camera_p3d.cuda(), raster_settings=raster_settings)
    rasterized = rasterizer(points)

    image = None
    if build_image:
        renderer = PointsRenderer(
            rasterizer=rasterizer,
            # Pass in background_color to the alpha compositor, setting the background color 
            # to the 3 item tuple, representing rgb on a scale of 0 -> 1, in this case blue
            compositor=NormWeightedCompositor()
        )

        image = renderer(points)

    fraction_set = set(torch.unique(rasterized.idx)[1:].tolist())

    return fraction_set, image

def compute_iou_2sets(set0, set1):

    intersection_indices = set0.intersection(set1)
    union_indices = set0.union(set1)
    iou = len(intersection_indices)/len(union_indices)

    return iou, list(intersection_indices), list(union_indices)

def create_point_actor(points, colors):
    """ open3d point cloud from numpy array """
    point_cloud = o3d.geometry.PointCloud()
    point_cloud.points = o3d.utility.Vector3dVector(points)
    point_cloud.colors = o3d.utility.Vector3dVector(colors)
    point_cloud.normals = o3d.utility.Vector3dVector(np.zeros_like(points))
    return point_cloud

def rotmat2qvec(R):
    Rxx, Ryx, Rzx, Rxy, Ryy, Rzy, Rxz, Ryz, Rzz = R.flat
    K = np.array([
        [Rxx - Ryy - Rzz, 0, 0, 0],
        [Ryx + Rxy, Ryy - Rxx - Rzz, 0, 0],
        [Rzx + Rxz, Rzy + Ryz, Rzz - Rxx - Ryy, 0],
        [Ryz - Rzy, Rzx - Rxz, Rxy - Ryx, Rxx + Ryy + Rzz]]) / 3.0
    eigvals, eigvecs = np.linalg.eigh(K)
    qvec = eigvecs[[3, 0, 1, 2], np.argmax(eigvals)]
    if qvec[0] < 0:
        qvec *= -1
    return qvec

def qvec2rotmat(qvec):
    return np.array([
        [1 - 2 * qvec[2]**2 - 2 * qvec[3]**2,
         2 * qvec[1] * qvec[2] - 2 * qvec[0] * qvec[3],
         2 * qvec[3] * qvec[1] + 2 * qvec[0] * qvec[2]],
        [2 * qvec[1] * qvec[2] + 2 * qvec[0] * qvec[3],
         1 - 2 * qvec[1]**2 - 2 * qvec[3]**2,
         2 * qvec[2] * qvec[3] - 2 * qvec[0] * qvec[1]],
        [2 * qvec[3] * qvec[1] - 2 * qvec[0] * qvec[2],
         2 * qvec[2] * qvec[3] + 2 * qvec[0] * qvec[1],
         1 - 2 * qvec[1]**2 - 2 * qvec[2]**2]])

# %%
room_name = 'office_2'

# replica_poses_basedir = '/mnt/sdb1/home/kbotashev/iros_paper/replica_dataset_1/prepared_scenes_poses_replica'

output_basedir = '/mnt/sdb1/home/kbotashev/iros_paper/replica_dataset_1/scenes'

room_output_dir = os.path.join(output_basedir, room_name)
os.makedirs(room_output_dir, exist_ok=True)

replica_poses_dir = '/mnt/sdb1/home/kbotashev/iros_paper/replica_dataset_1/scenes/office_2/office_2_rebase/office_2_rebase_raw_poses'

interpolation = 2 if '_rebase' in replica_poses_dir else 1

scene_name = replica_poses_dir.split('/')[-1]

print(scene_name)

replica_output_dir = os.path.join(room_output_dir, scene_name, scene_name+'_raw')

scene_output_dir = os.path.join(room_output_dir, scene_name)

os.makedirs(replica_output_dir, exist_ok=True)

print('### STARTED REPLICA EXTRACTOR FOR ' + scene_name)

command = ['cd /mnt/sdb1/nerf_datasets/replica/replica-gen/ &&'
            '/mnt/sdb1/home/vpyatov/anaconda3/envs/habitat/bin/python', 
            '/mnt/sdb1/nerf_datasets/replica/replica-gen/src/example.py',
            '--dataset=/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/replica.scene_dataset_config.json',
            '--scene='+room_name,
            '--depth_sensor',
            '--height=1080',
            '--width=1920',
            '--interpolation='+str(interpolation),
            '--poses='+replica_poses_dir,
            '--output_path='+replica_output_dir]

subprocess.run(' '.join(command), shell=True)

#---------------------------------------------------------------------------------------
print('### FINISHED REPLICA EXTRACTOR, STARTING FORMING PCs FOR ' + scene_name)
new_dataset_dir = scene_output_dir


with open(os.path.join(replica_output_dir, 'cam_params.json')) as fp:
    camera_params = json.load(fp)['camera']

with open(os.path.join(replica_output_dir, 'transforms.json')) as fp:
    transforms = json.load(fp)    

renamed_images_dir = os.path.join(new_dataset_dir, 'images')
os.makedirs(renamed_images_dir, exist_ok=True)
colmap_emulation_dir = os.path.join(new_dataset_dir, 'sparse', '0')
os.makedirs(colmap_emulation_dir, exist_ok=True)
images_txt_path = os.path.join(colmap_emulation_dir, 'images.txt')
cameras_txt_path = os.path.join(colmap_emulation_dir, 'cameras.txt')

K = np.array([[camera_params['fx'], 0, camera_params['cx']],
            [0, camera_params['fy'], camera_params['cy']],
            [0, 0, 1]])

with open(cameras_txt_path, 'w') as camfwid:
    line_elems = ['1', 'PINHOLE', str(int(camera_params['w'])), str(int(camera_params['h'])), 
                str(camera_params['fx']), str(camera_params['fy']),
                str(camera_params['cx']), str(camera_params['cy'])]
    camfwid.write(' '.join(line_elems))

keypoints_only = False
decimation_factor = 100
general_noise_intensity = 0
peak_noise_intensity = 0
peak_pose_noise = mrob.geometry.SE3(np.random.rand(6)*peak_noise_intensity)
peak_noised_cam_indices = np.arange(40,50)

poses = []
colors = []
pcs = []
sift = cv2.SIFT_create()

poses = {}
with open(images_txt_path, "w") as fwid:
    for frame_info in tqdm(transforms['frames']):
        image_path = frame_info['file_path']
        depth_path = frame_info['depth_path']

        image = imageio.imread(os.path.join(replica_output_dir, image_path))/255
        depth = cv2.imread(os.path.join(replica_output_dir, depth_path), cv2.IMREAD_ANYDEPTH)/camera_params['scale']

        cam2world = np.array(frame_info['transform_matrix'])@np.diag([1,-1,-1,1])

        image_num_str = image_path.split('image.')[-1].split('.png')[0]

        poses[image_num_str + '.png'] = cam2world.tolist()

        if general_noise_intensity > 0 and int(image_num_str) not in peak_noised_cam_indices:
            general_pose_noise = mrob.geometry.SE3(np.random.rand(6)*general_noise_intensity)
            cam2world = general_pose_noise.mul(mrob.geometry.SE3(cam2world)).T()

        if int(image_num_str) in peak_noised_cam_indices and peak_noise_intensity > 0:
            cam2world = peak_pose_noise.mul(mrob.geometry.SE3(cam2world)).T()

        world2cam = np.linalg.inv(cam2world)
        
        line_elems = [str(int(image_num_str))]
        tvec = world2cam[:-1,-1]
        rot = world2cam[:3,:3]
        line_elems += rotmat2qvec(rot).astype(str).tolist()
        line_elems += tvec.astype(str).tolist()
        line_elems.append(str(1))
        line_elems.append(image_num_str + '.png')
        fwid.write(' '.join(line_elems))
        fwid.write('\n')
        fwid.write(' '.join(['1', '2', '3']))
        fwid.write('\n')

        u = np.arange(image.shape[1])
        v = np.arange(image.shape[0])

        uu, vv = np.meshgrid(u, v)
        pixs = np.stack([uu, vv, np.ones_like(vv)],-1)

        Kinv_P = np.einsum('ij,bcj->bci', np.linalg.inv(K), pixs)
        D_Kinv_P = np.concatenate([np.multiply(np.expand_dims(depth,-1), Kinv_P), np.expand_dims(np.ones_like(depth),-1)], -1)
        pcd = np.einsum('ij,bcj->bci', cam2world, D_Kinv_P)[:,:,:-1]
        if keypoints_only:
            image_gray = cv2.imread(os.path.join(replica_output_dir, image_path), cv2.IMREAD_GRAYSCALE)
            kps, dess = sift.detectAndCompute(image_gray, None)
            keypoint_coords = np.array([keypoint.pt[::-1] for keypoint in kps]).astype(int)
            image = image[tuple(keypoint_coords.T)].tolist()
            pcd = pcd[tuple(keypoint_coords.T)].tolist()
            decimation_factor = 1
        else:
            image = image.reshape(-1,3).tolist()[::decimation_factor]
            pcd = pcd.reshape(-1,3).tolist()[::decimation_factor]
        colors += image
        pcs += pcd
        shutil.copy(os.path.join(replica_output_dir, image_path), os.path.join(renamed_images_dir, image_num_str + '.png'))

with open(os.path.join(colmap_emulation_dir, "poses_c2w_gt.json"), "w") as outfile:
    json.dump(poses, outfile, indent = 4)
result_point_actor = create_point_actor(np.array(pcs).reshape(-1, 3), np.array(colors).reshape(-1, 3))
o3d.io.write_point_cloud(os.path.join(colmap_emulation_dir, 'points3D.ply'), result_point_actor.voxel_down_sample(voxel_size=0.025))
print('### FINISHED FORMING PCs FOR ' + scene_name)
# Out:
# office_2_rebase_raw_poses
# ### STARTED REPLICA EXTRACTOR FOR office_2_rebase_raw_poses
# sim_cfg.physics_config_file = data/default.physics_config.json
# [16:31:41:867660]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Dataset>: Proposing JSON name : default.scene_dataset_config.json from original name : default| This file does not exist.
# [16:31:41:867940]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (capsule3DSolid:capsule3DSolid_hemiRings_4_cylRings_1_segments_12_halfLen_0.75_useTexCoords_false_useTangents_false) created and registered.
# [16:31:41:867970]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (capsule3DWireframe:capsule3DWireframe_hemiRings_8_cylRings_1_segments_16_halfLen_1) created and registered.
# [16:31:41:867988]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (coneSolid:coneSolid_segments_12_halfLen_1.25_rings_1_useTexCoords_false_useTangents_false_capEnd_true) created and registered.
# [16:31:41:868019]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (coneWireframe:coneWireframe_segments_32_halfLen_1.25) created and registered.
# [16:31:41:868032]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (cubeSolid:cubeSolid) created and registered.
# [16:31:41:868044]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (cubeWireframe:cubeWireframe) created and registered.
# [16:31:41:868057]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (cylinderSolid:cylinderSolid_rings_1_segments_12_halfLen_1_useTexCoords_false_useTangents_false_capEnds_true) created and registered.
# [16:31:41:868071]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (cylinderWireframe:cylinderWireframe_rings_1_segments_32_halfLen_1) created and registered.
# [16:31:41:868083]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (icosphereSolid:icosphereSolid_subdivs_1) created and registered.
# [16:31:41:868096]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (icosphereWireframe:icosphereWireframe_subdivs_1) created and registered.
# [16:31:41:868109]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (uvSphereSolid:uvSphereSolid_rings_8_segments_16_useTexCoords_false_useTangents_false) created and registered.
# [16:31:41:868121]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (uvSphereWireframe:uvSphereWireframe_rings_16_segments_32) created and registered.
# [16:31:41:868130]:[Metadata] AssetAttributesManager.cpp(112)::AssetAttributesManager : Built default primitive asset templates : 12
# [16:31:41:868303]:[Metadata] SceneDatasetAttributesManager.cpp(37)::createObject : File (default) not found, so new default dataset attributes created  and registered.
# [16:31:41:868313]:[Metadata] MetadataMediator.cpp(120)::createSceneDataset : Dataset default successfully created.
# [16:31:41:868323]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Physics Manager>: Proposing JSON name : ./data/default.physics_config.json from original name : ./data/default.physics_config.json| This file does not exist.
# [16:31:41:868336]:[Metadata] PhysicsAttributesManager.cpp(26)::createObject : File (./data/default.physics_config.json) not found, so new default physics manager attributes created and registered.
# [16:31:41:868344]:[Metadata] MetadataMediator.cpp(210)::setActiveSceneDatasetName : Attempting to create new dataset /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/replica.scene_dataset_config.json
# [16:31:41:868354]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Dataset>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/replica.scene_dataset_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/replica.scene_dataset_config.json| This file exists.
# [16:31:41:873506]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (capsule3DSolid:capsule3DSolid_hemiRings_4_cylRings_1_segments_12_halfLen_0.75_useTexCoords_false_useTangents_false) created and registered.
# [16:31:41:873610]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (capsule3DWireframe:capsule3DWireframe_hemiRings_8_cylRings_1_segments_16_halfLen_1) created and registered.
# [16:31:41:873673]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (coneSolid:coneSolid_segments_12_halfLen_1.25_rings_1_useTexCoords_false_useTangents_false_capEnd_true) created and registered.
# [16:31:41:873730]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (coneWireframe:coneWireframe_segments_32_halfLen_1.25) created and registered.
# [16:31:41:873775]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (cubeSolid:cubeSolid) created and registered.
# [16:31:41:873814]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (cubeWireframe:cubeWireframe) created and registered.
# [16:31:41:873828]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (cylinderSolid:cylinderSolid_rings_1_segments_12_halfLen_1_useTexCoords_false_useTangents_false_capEnds_true) created and registered.
# [16:31:41:873841]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (cylinderWireframe:cylinderWireframe_rings_1_segments_32_halfLen_1) created and registered.
# [16:31:41:873855]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (icosphereSolid:icosphereSolid_subdivs_1) created and registered.
# [16:31:41:873870]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (icosphereWireframe:icosphereWireframe_subdivs_1) created and registered.
# [16:31:41:873883]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (uvSphereSolid:uvSphereSolid_rings_8_segments_16_useTexCoords_false_useTangents_false) created and registered.
# [16:31:41:873897]:[Metadata] AssetAttributesManager.cpp(123)::createObject : Asset attributes (uvSphereWireframe:uvSphereWireframe_rings_16_segments_32) created and registered.
# [16:31:41:873906]:[Metadata] AssetAttributesManager.cpp(112)::AssetAttributesManager : Built default primitive asset templates : 12
# [16:31:41:874266]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/apartment_0/habitat
# [16:31:41:874280]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/apartment_0/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/apartment_0/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:874672]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/apartment_0/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:874684]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:874701]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/apartment_1/habitat
# [16:31:41:874710]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/apartment_1/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/apartment_1/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:874991]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/apartment_1/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:875000]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:875017]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/apartment_2/habitat
# [16:31:41:875025]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/apartment_2/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/apartment_2/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:879958]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/apartment_2/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:879982]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:880002]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_0/habitat
# [16:31:41:880012]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_0/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_0/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:889942]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_0/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:889965]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:889985]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_1/habitat
# [16:31:41:889995]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_1/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_1/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:897213]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_1/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:897279]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:897333]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_2/habitat
# [16:31:41:897343]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_2/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_2/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:903648]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_2/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:903671]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:903691]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_3/habitat
# [16:31:41:903700]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_3/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_3/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:903957]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_3/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:903969]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:903986]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_4/habitat
# [16:31:41:903995]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_4/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_4/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:904168]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_4/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:904179]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:904196]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_5/habitat
# [16:31:41:904204]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_5/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_5/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:913400]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_5/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:913424]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:913446]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/hotel_0/habitat
# [16:31:41:913455]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/hotel_0/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/hotel_0/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:942676]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/hotel_0/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:942699]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:942720]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_0/habitat
# [16:31:41:942729]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_0/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_0/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:943004]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_0/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:943016]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:943034]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_1/habitat
# [16:31:41:943042]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_1/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_1/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:950129]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_1/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:950152]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:950172]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat
# [16:31:41:950181]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:950221]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:950230]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:950245]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_3/habitat
# [16:31:41:950254]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_3/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_3/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:958294]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_3/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:958317]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:958338]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_4/habitat
# [16:31:41:958347]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_4/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_4/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:958867]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_4/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:958879]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:958897]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/room_0/habitat
# [16:31:41:958906]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/room_0/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/room_0/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:972926]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/room_0/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:972950]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:972972]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/room_1/habitat
# [16:31:41:972981]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/room_1/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/room_1/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:978366]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/room_1/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:978390]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:978411]:[Metadata] AttributesManagerBase.h(265)::loadAllFileBasedTemplates : Loading 1  Stage Template templates found in /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/room_2/habitat
# [16:31:41:978420]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Stage Template>: Proposing JSON name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/room_2/habitat/replica_stage.stage_config.json from original name : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/room_2/habitat/replica_stage.stage_config.json| This file exists.
# [16:31:41:979756]:[Metadata] AbstractObjectAttributesManagerBase.h(184)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/room_2/habitat/replica_stage.stage_config.json) based Stage Template attributes created and registered.
# [16:31:41:979779]:[Metadata] AttributesManagerBase.h(285)::loadAllFileBasedTemplates : <Stage Template> : Loaded file-based templates: 1
# [16:31:41:979786]:[Metadata] AttributesManagerBase.h(360)::buildAttrSrcPathsFromJSONAndLoad : <Stage Template>:1paths specified in JSON doc forStage Templatetemplates.
# [16:31:41:979849]:[Metadata] SceneDatasetAttributesManager.cpp(37)::createObject : JSON Configuration File (/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/replica.scene_dataset_config.json) based dataset attributes created  and registered.
# [16:31:41:979856]:[Metadata] MetadataMediator.cpp(120)::createSceneDataset : Dataset /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/replica.scene_dataset_config.json successfully created.
# [16:31:41:979864]:[Metadata] MetadataMediator.cpp(217)::setActiveSceneDatasetName : Attempt to create new dataset /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/replica.scene_dataset_config.json   succeeded. Currently active dataset : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/replica.scene_dataset_config.json
# [16:31:41:979873]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Physics Manager>: Proposing JSON name : data/default.physics_config.json from original name : data/default.physics_config.json| This file does not exist.
# [16:31:41:979886]:[Metadata] PhysicsAttributesManager.cpp(26)::createObject : File (data/default.physics_config.json) not found, so new default physics manager attributes created and registered.
# [16:31:41:979895]:[Metadata] MetadataMediator.cpp(66)::setSimulatorConfiguration : Set new simulator config for scene/stage : office_2 and dataset : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/replica.scene_dataset_config.json which is currently active dataset.
# [16:31:41:874106]:[Metadata] SceneDatasetAttributesManager.cpp(310)::readDatasetJSONCell : "stages.default_attributes" set in Attributes Manager from JSON.
# [16:31:41:874253]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/apartment_0/habitat/replica_stage.stage_config.json
# [16:31:41:874689]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/apartment_1/habitat/replica_stage.stage_config.json
# [16:31:41:875006]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/apartment_2/habitat/replica_stage.stage_config.json
# [16:31:41:879989]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_0/habitat/replica_stage.stage_config.json
# [16:31:41:889972]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_1/habitat/replica_stage.stage_config.json
# [16:31:41:897301]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_2/habitat/replica_stage.stage_config.json
# [16:31:41:903677]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_3/habitat/replica_stage.stage_config.json
# [16:31:41:903974]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_4/habitat/replica_stage.stage_config.json
# [16:31:41:904184]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/frl_apartment_5/habitat/replica_stage.stage_config.json
# [16:31:41:913430]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/hotel_0/habitat/replica_stage.stage_config.json
# [16:31:41:942705]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_0/habitat/replica_stage.stage_config.json
# [16:31:41:943022]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_1/habitat/replica_stage.stage_config.json
# [16:31:41:950159]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/replica_stage.stage_config.json
# [16:31:41:950235]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_3/habitat/replica_stage.stage_config.json
# [16:31:41:958324]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_4/habitat/replica_stage.stage_config.json
# [16:31:41:958885]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/room_0/habitat/replica_stage.stage_config.json
# [16:31:41:972957]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/room_1/habitat/replica_stage.stage_config.json
# [16:31:41:978397]:[Metadata] AttributesManagerBase.h(352)::buildAttrSrcPathsFromJSONAndLoad : Glob path result for /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/*_[0-9]/habitat/replica_stage.stage_config.json : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/room_2/habitat/replica_stage.stage_config.json
# [16:31:41:979810]:[Metadata] SceneInstanceAttributesManager.cpp(67)::setValsFromJSONDoc : No Stage specified for scene default_attributes , or specification error.
# [16:31:41:979820]:[Metadata] SceneInstanceAttributesManager.cpp(107)::setValsFromJSONDoc : No Articulated Objects specified for scene default_attributes , or specification error.
# [16:31:41:979826]:[Metadata] SceneInstanceAttributesManager.cpp(127)::setValsFromJSONDoc : No navmesh_instance specified for scene default_attributes .
# [16:31:41:979832]:[Metadata] SceneInstanceAttributesManager.cpp(137)::setValsFromJSONDoc : No semantic_scene_instance specified for scene default_attributes .
# [16:31:41:979838]:[Metadata] SceneDatasetAttributesManager.cpp(310)::readDatasetJSONCell : "scene_instances.default_attributes" set in Attributes Manager from JSON.
# Renderer: Tesla V100-PCIE-16GB/PCIe/SSE2 by NVIDIA Corporation
# OpenGL version: 4.6.0 NVIDIA 510.108.03
# Using optional features:
#     GL_ARB_vertex_array_object
#     GL_ARB_ES2_compatibility
#     GL_ARB_separate_shader_objects
#     GL_ARB_robustness
#     GL_ARB_texture_storage
#     GL_ARB_invalidate_subdata
#     GL_ARB_texture_storage_multisample
#     GL_ARB_multi_bind
#     GL_ARB_direct_state_access
#     GL_ARB_get_texture_sub_image
#     GL_ARB_texture_filter_anisotropic
#     GL_KHR_debug
#     GL_KHR_parallel_shader_compile
# Using driver workarounds:
#     no-forward-compatible-core-context
#     nv-egl-incorrect-gl11-function-pointers
#     no-layout-qualifiers-on-old-glsl
#     nv-zero-context-profile-mask
#     nv-implementation-color-read-format-dsa-broken
#     nv-cubemap-inconsistent-compressed-image-size
#     nv-cubemap-broken-full-compressed-image-query
#     nv-compressed-block-size-in-bits
# [16:31:42:304031]:[Metadata] MetadataMediator.cpp(279)::getSceneInstanceAttributesByName : No existing scene instance attributes containing name office_2 found in Dataset : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/replica.scene_dataset_config.json but 1 StageAttributes found.  Using /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/replica_stage.stage_config.json as stage and to construct a SceneInstanceAttributes with same name that will be added to Dataset.
# [16:31:42:304139]:[Metadata] SceneDatasetAttributes.cpp(47)::addNewSceneInstanceToDataset : Dataset : 'replica' : Stage Attributes '/mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/replica_stage.stage_config.json' specified in Scene Attributes exists in dataset library.
# [16:31:42:304152]:[Metadata] SceneDatasetAttributes.cpp(84)::addNewSceneInstanceToDataset : Dataset : 'replica' : Lighting Layout Attributes 'no_lights' specified in Scene Attributes but does not exist in dataset, so creating.
# [16:31:42:304171]:[Metadata] AttributesManagerBase.h(380)::createFromJsonOrDefaultInternal : <Lighting Layout>: Proposing JSON name : no_lights.lighting_config.json from original name : no_lights| This file does not exist.
# [16:31:42:304195]:[Metadata] LightLayoutAttributesManager.cpp(38)::createObject : File (no_lights) not found, so new default light layout attributes created and registered.
# [16:31:42:304212]:[Sim] Simulator.cpp(240)::createSceneInstance : Navmesh file location in scene instance : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/mesh_semantic.navmesh
# [16:31:42:304235]:[Sim] Simulator.cpp(245)::createSceneInstance : Loading navmesh from /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/mesh_semantic.navmesh
# [16:31:42:329849]:[Nav] PathFinder.cpp(1032)::loadNavMesh : NavMeshSettings aren't present, guessing that they are the default
# [16:31:42:329950]:[Sim] Simulator.cpp(247)::createSceneInstance : Navmesh Loaded.
# [16:31:42:330061]:[Scene] SceneGraph.h(85)::createDrawableGroup : Created DrawableGroup:
# [16:31:42:330078]:[Assets] ResourceManager.cpp(308)::loadSemanticSceneDescriptor : SceneInstance : office_2 proposed Semantic Scene Descriptor filename : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/info_semantic.json
# [16:31:42:337209]:[Assets] ResourceManager.cpp(319)::loadSemanticSceneDescriptor : SSD with SceneInstanceAttributes-provided name  /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/info_semantic.json successfully found and loaded
# [16:31:42:337311]:[Assets] ResourceManager.cpp(1666)::configureImporterManagerGLExtensions : Importing Basis files as BC7.
# [16:31:42:338138]:[Sim] Simulator.cpp(305)::createSceneInstance : Using scene instance-specified Light key : - no_lights -
# [16:31:42:338193]:[Metadata] MetadataMediator.cpp(66)::setSimulatorConfiguration : Set new simulator config for scene/stage : office_2 and dataset : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/replica.scene_dataset_config.json which is currently active dataset.
# [16:31:42:338277]:[Sim] Simulator.cpp(415)::instanceStageForSceneAttributes : Start to load stage named : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/replica_stage.stage_config.json with render asset : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/../mesh.ply and collision asset : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/../mesh.ply
# [16:31:42:338403]:[Assets] ResourceManager.cpp(702)::createStageAssetInfosFromAttributes : Frame :{"up":[0,0,1],"front":[0,1,0],"origin":[0,0,0]} for render mesh named : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/../mesh.ply|{"up":[0,1,0],"front":[0,0,-1],"origin":[0,0,0]} for semantic mesh named : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/mesh_semantic.ply with type specified as semantic|Semantic Txtrs : False
# [16:31:42:338441]:[Assets] ResourceManager.cpp(442)::loadStage : Loading Semantic Stage mesh : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/mesh_semantic.ply
# [16:31:42:338462]:[Scene] SceneGraph.h(85)::createDrawableGroup : Created DrawableGroup:
# [16:31:42:338481]:[Assets] ResourceManager.cpp(984)::loadStageInternal : Attempting to load stage /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/mesh_semantic.ply
# [16:31:42:338508]:[Assets] ResourceManager.cpp(863)::loadRenderAsset : Loading Semantic Mesh asset named: /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/mesh_semantic.ply
# [16:31:42:338539]:[Assets] ResourceManager.cpp(1666)::configureImporterManagerGLExtensions : Importing Basis files as BC7.
# [16:31:43:768951]:[Assets] ResourceManager.cpp(475)::loadStage : Semantic Stage mesh : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/mesh_semantic.ply loaded.
# [16:31:43:769008]:[Assets] ResourceManager.cpp(518)::loadStage : Start load render asset /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/../mesh.ply .
# [16:31:43:769015]:[Assets] ResourceManager.cpp(984)::loadStageInternal : Attempting to load stage /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/../mesh.ply
# [16:31:43:769034]:[Assets] ResourceManager.cpp(860)::loadRenderAsset : Loading PTEX asset named: /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/../mesh.ply
# [16:31:43:946170]:[Assets] PTexMeshData.cpp(475)::loadMeshData : Splitting mesh...
# [16:31:44:257641]:[Assets] PTexMeshData.cpp(382)::loadSubMeshes : The number of quads: 857845 , which equals to 1715690 triangles.
# [16:31:44:258981]:[Assets] PTexMeshData.cpp(831)::uploadBuffersToGPU : Loading mesh 1 / 8 ...
# [16:31:44:264781]:[Assets] PTexMeshData.cpp(831)::uploadBuffersToGPU : Loading mesh 2 / 8 ...
# [16:31:44:285339]:[Assets] PTexMeshData.cpp(831)::uploadBuffersToGPU : Loading mesh 3 / 8 ...
# [16:31:44:289090]:[Assets] PTexMeshData.cpp(831)::uploadBuffersToGPU : Loading mesh 4 / 8 ...
# [16:31:44:293661]:[Assets] PTexMeshData.cpp(831)::uploadBuffersToGPU : Loading mesh 5 / 8 ...
# [16:31:44:293887]:[Assets] PTexMeshData.cpp(831)::uploadBuffersToGPU : Loading mesh 6 / 8 ...
# [16:31:44:295436]:[Assets] PTexMeshData.cpp(831)::uploadBuffersToGPU : Loading mesh 7 / 8 ...
# [16:31:44:300895]:[Assets] PTexMeshData.cpp(831)::uploadBuffersToGPU : Loading mesh 8 / 8 ...
# [16:31:44:301489]:[Assets] PTexMeshData.cpp(857)::uploadBuffersToGPU : Calculating mesh adjacency...
# [16:31:44:829296]:[Assets] PTexMeshData.cpp(904)::uploadBuffersToGPU : loading atlas textures:
# [16:31:44:829381]:[Assets] PTexMeshData.cpp(913)::uploadBuffersToGPU : Loading atlas 1 / 8 from /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/../textures/0-color-ptex.hdr .
# [16:31:45:569359]:[Assets] PTexMeshData.cpp(913)::uploadBuffersToGPU : Loading atlas 2 / 8 from /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/../textures/1-color-ptex.hdr .
# [16:31:46:036098]:[Assets] PTexMeshData.cpp(913)::uploadBuffersToGPU : Loading atlas 3 / 8 from /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/../textures/2-color-ptex.hdr .
# [16:31:46:554053]:[Assets] PTexMeshData.cpp(913)::uploadBuffersToGPU : Loading atlas 4 / 8 from /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/../textures/3-color-ptex.hdr .
# [16:31:47:199515]:[Assets] PTexMeshData.cpp(913)::uploadBuffersToGPU : Loading atlas 5 / 8 from /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/../textures/4-color-ptex.hdr .
# [16:31:47:217065]:[Assets] PTexMeshData.cpp(913)::uploadBuffersToGPU : Loading atlas 6 / 8 from /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/../textures/5-color-ptex.hdr .
# [16:31:47:411152]:[Assets] PTexMeshData.cpp(913)::uploadBuffersToGPU : Loading atlas 7 / 8 from /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/../textures/6-color-ptex.hdr .
# [16:31:47:744900]:[Assets] PTexMeshData.cpp(913)::uploadBuffersToGPU : Loading atlas 8 / 8 from /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/../textures/7-color-ptex.hdr .
# [16:31:47:886100]:[Sim] Simulator.cpp(442)::instanceStageForSceneAttributes : Successfully loaded stage named : /mnt/sdb1/home/kbotashev/mip-nerf_projects/data/replica_dataset/office_2/habitat/replica_stage.stage_config.json
# [16:31:47:886155]:[Sim] Simulator.cpp(208)::reconfigure : CreateSceneInstance success == true for active scene name : office_2  with renderer.
# start_state.position	 [-0.16765113 -0.42650455 -2.6228142 ] start_state.rotation	 quaternion(1, 0, 2.45858027483337e-05, 0)
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 100%|██████████| 570/570 [01:51<00:00,  5.10it/s]
# [16:33:40:044449]:[Physics] PhysicsManager.cpp(54)::~PhysicsManager : Deconstructing PhysicsManager
# [16:33:40:044539]:[Scene] SceneManager.h(24)::~SceneManager : Deconstructing SceneManager
# [16:33:40:044547]:[Scene] SceneGraph.h(25)::~SceneGraph : Deconstructing SceneGraph
# [16:33:40:046087]:[Sensor] Sensor.cpp(69)::~Sensor : Deconstructing Sensor
# [16:33:40:047703]:[Sensor] Sensor.cpp(69)::~Sensor : Deconstructing Sensor
# [16:33:40:047731]:[Scene] SceneGraph.h(25)::~SceneGraph : Deconstructing SceneGraph
# [16:33:40:047959]:[Scene] SemanticScene.h(48)::~SemanticScene : Deconstructing SemanticScene
# [16:33:40:167292]:[Gfx] Renderer.cpp(71)::~Impl : Deconstructing Renderer
# [16:33:40:167357]:[Gfx] WindowlessContext.h(17)::~WindowlessContext : Deconstructing WindowlessContext
# [16:33:40:175643]:[Sim] Simulator.cpp(69)::~Simulator : Deconstructing Simulator
#  ========================= Performance ========================
#  1920 x 1080, total time 111.97 s, frame time 196.433 ms (5.1 FPS)
#  ==============================================================
# ### FINISHED REPLICA EXTRACTOR, STARTING FORMING PCs FOR office_2_rebase_raw_poses
#   7%|▋         | 42/570 [05:47<1:33:20, 10.61s/it]Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7effe91b4940>>
# Traceback (most recent call last):
#   File "/mnt/sdb1/home/kbotashev/anaconda3/envs/gs102/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 770, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
#   8%|▊         | 43/570 [05:59<1:36:49, 11.02s/it]

# %%
from pytorch3d import io
import torch
from pytorch3d.renderer.cameras import FoVPerspectiveCameras, PerspectiveCameras
from pytorch3d.renderer.points.rasterizer import PointsRasterizer, PointsRasterizationSettings
from pytorch3d.structures import Pointclouds
from pytorch3d.utils import cameras_from_opencv_projection 
from pytorch3d.renderer import (
    PointsRenderer,
    NormWeightedCompositor
)

from scene.dataset_readers import readColmapSceneInfo
from utils.camera_utils import loadCam
from collections import namedtuple
import open3d as o3d
import matplotlib.pyplot as plt
import numpy as np
import mrob
from tqdm import tqdm
from joblib import Parallel, delayed
import os
import pickle
import cv2
import shutil

from gaussian_renderer import GaussianModel

# %%
task_dir_path = '/mnt/sdb1/home/kbotashev/iros_paper/ibr_dataset/scenes/playroom/playroom_base'
scene_info = readColmapSceneInfo(task_dir_path, 'images_full', eval=True)
# Out:
# Reading camera 225/225

# %%
out_dir = '/mnt/sdb1/home/kbotashev/iros_paper/ibr_dataset/scenes/playroom/playroom_task/images'
for cam_info in tqdm(scene_info.test_cameras): 
    shutil.copy(cam_info.image_path, out_dir)
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 1316.18it/s]

# %% [markdown]
# ### REPLICA REBASE

# %%
import numpy as np
np.random.seed(42)
import torch
torch.manual_seed(42)
torch.cuda.manual_seed_all(42)
import random
random.seed(42)

import os
import subprocess
from tqdm import tqdm
from os import makedirs
from gaussian_renderer import render_lie, render_qtvec
import torchvision
from utils.general_utils import safe_state
from argparse import ArgumentParser
from arguments import ModelParams, PipelineParams, get_combined_args, pose_estimation_params
from gaussian_renderer import GaussianModel
from utils.image_utils import psnr
from utils.loss_utils import EdgeDetection
import numpy as np
from utils.loss_utils import l1_loss, ssim, l2_loss
from copy import deepcopy
from torchmetrics.image.lpip import LearnedPerceptualImagePatchSimilarity as LPIPS
import pypose as pp

from scene.dataset_readers import readColmapSceneInfo
from utils.camera_utils import loadCam
from collections import namedtuple
from matplotlib import pyplot as plt


import torch
import math
from diff_gaussian_rasterization_lie_pp import GaussianRasterizationSettings, GaussianRasterizer
from scene.gaussian_model import GaussianModel
from utils.sh_utils import eval_sh

import pickle

from scene.dataset_readers import CameraInfo
from PIL import Image
import mrob
import open3d as o3d

from arguments import  pose_estimation_params
from utils.general_utils import get_expon_lr_func
import cv2
from glob import glob
import copy
import json
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
room_name = 'apartment_1'
experiments_base_dir = '/mnt/sdb1/home/kbotashev/iros_paper/replica_dataset_1'

ply_path = os.path.join(experiments_base_dir, 
                        'output', room_name, 
                        'point_cloud/iteration_40000/point_cloud.ply')

gaussians = GaussianModel(sh_degree=3)
gaussians.load_ply(ply_path)

# %%
task_dir_path = os.path.join('/mnt/sdb1/home/kbotashev/iros_paper/replica_dataset_1/scenes/', room_name, room_name + '_rebase')
scene_info = readColmapSceneInfo(task_dir_path, 'images_original', eval=False)
# Out:
# Reading camera 148/148

# %%
args = namedtuple('args', ['resolution', 'data_device'])
args = args(1, 'cuda')

pipe = namedtuple('pipe', ['convert_SHs_python', 'compute_cov3D_python', 'debug'])
pipe = pipe(False, False, False)

bg_color = [0, 0, 0]
background = torch.tensor(bg_color, dtype=torch.float32, device="cuda")
os.makedirs(os.path.join(task_dir_path, 'images'), exist_ok=True)
for id in tqdm(range(len(scene_info.train_cameras))):
    cam_info = scene_info.train_cameras[id]
    camera = loadCam(args=args, id = id, cam_info=cam_info, resolution_scale=1, camera_type='lietorch')
    image_render = render_lie(camera, gaussians, pipe, background)["render"]
    image_render = torch.clamp(image_render, 0, 1)

    norm_image = cv2.normalize(image_render.detach().cpu().numpy().transpose(1,2,0), None, alpha = 0, beta = 255, norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F)

    norm_image = norm_image.astype(np.uint8)
    # break
    cv2.imwrite(os.path.join(task_dir_path, 'images', cam_info.image_name + '.png'), cv2.cvtColor(norm_image, cv2.COLOR_RGB2BGR))
    # break
# Out:
# 100%|██████████| 148/148 [00:26<00:00,  5.59it/s]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
